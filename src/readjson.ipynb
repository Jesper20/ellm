# %%
import pandas as pd

# %%
input_file = "../workstation/output.json"

# %%
data_df = pd.read_json(input_file, lines=True)

data_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 data_df = pd.read_json(input_file, lines=True)
#       3 data_df
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py:207, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     205     else:
#     206         kwargs[new_arg_name] = new_arg_value
# --> 207 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# ...

# %%
with open(input_file, 'r') as f:
    data = f.readlines()

# %%
data

# %%
import json
import pandas as pd

input_file = "../workstation/output.json"
with open(input_file, 'r') as f:
    data = json.load(f)

df = pd.DataFrame(data)

df
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Input In [4], in <cell line: 5>()
#       4 input_file = "../workstation/output.json"
#       5 with open(input_file, 'r') as f:
# ----> 6     data = json.load(f)
#       8 df = pd.DataFrame(data)
#      10 df
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/json/__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
# ...

# %%
import pandas as pd   

file_path = "../erik/train.jsonl"
jsonObj = pd.read_json(path_or_buf=file_path, lines=True)

# %%
jsonObj
# Out:
#                                            conversations  \
# 0      [{'user': 'human', 'text': 'A + B means A is t...
# 1      [{'user': 'human', 'text': 'Web search results...
# 2      [{'user': 'human', 'text': 'who is andrew tate...
# 3      [{'user': 'human', 'text': 'Web search results...
# 4      [{'user': 'human', 'text': 'write a walmart pr...
# ...                                                  ...
# 50491  [{'user': 'human', 'text': '<div><p class="">I...
# 50492  [{'user': 'human', 'text': '<div><p class="">C...
# 50493  [{'user': 'human', 'text': '<div><p class="">w...
# 50494  [{'user': 'human', 'text': '<div><p class="">w...
# 50495  [{'user': 'human', 'text': '<div><p class="">G...
#
#                                                       id lang
# 0                                                jhxaApn   en
# 1                                                w1hGtyw   en
# 2                                                UFtjCYJ   en
# ...

# %%
#!pip install pandas

import pandas as pd
import random 
# file_path = "../erik/train.jsonl"
#file_path = "../dataset/python-codes-25k.jsonl"
file_path = "../dataset/Code-Feedback.jsonl"

output_file = "../dataset/Code-Feedback_500.jsonl"

with open(file_path, "r") as f:
    lines = f.readlines()

i = 0
j = 1000
with open(output_file, "w") as f:    
    for line in lines:
        j+=1
        if j < 10000:
            continue
        rd = random.random()
        if i < 500:
            if rd > 0.8:
                f.write(line)
                i+=1
        else:
            break

# %%
#!pip install pandas

import pandas as pd
import random 
# file_path = "../erik/train.jsonl"
#file_path = "../dataset/python-codes-25k.jsonl"
# file_path = "../ds/Code-Feedback.jsonl"

# output_file = "../ds/Code-Feedback_300_10.jsonl"

file_path = "../ds/sharegpt-english.jsonl"

output_file = "../ds/sharegpt-english_100_10.jsonl"

with open(file_path, "r") as f:
    lines = f.readlines()

i = 0
with open(output_file, "w") as f:    
    for line in lines:
        i+=1
        if i > 900:
            f.write(line)   
        if i >= 1000:
            break

# %%
outjs = pd.read_json(path_or_buf=output_file, lines=True)

outjs
# Out:
#    id                                           messages
# 0   1  [{'role': 'user', 'content': 'Write a Ruby cod...
# 1   2  [{'role': 'user', 'content': 'Create a Python ...
# 2   3  [{'role': 'user', 'content': 'Please write a P...
# 3   4  [{'role': 'user', 'content': 'You are tasked w...
# 4   5  [{'role': 'user', 'content': 'Create an array ...
# 5   6  [{'role': 'user', 'content': 'You are asked to...
# 6   7  [{'role': 'user', 'content': 'You are tasked w...
# 7   8  [{'role': 'user', 'content': 'I have this prob...
# 8   9  [{'role': 'user', 'content': 'You are tasked w...
# 9  10  [{'role': 'user', 'content': 'Given an array o...
